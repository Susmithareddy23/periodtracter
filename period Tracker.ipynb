# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
period = pd.read_csv(r'C:\Users\sushmitha\Downloads\period tracker dataset\FedCycleData071012 (2).csv')
period
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0     nfp8122            1      0                   1                     0
# 1     nfp8122            2      0                   1                     0
# 2     nfp8122            3      0                   1                     0
# 3     nfp8122            4      0                   1                     0
# 4     nfp8122            5      0                   1                     0
# ...       ...          ...    ...                 ...                   ...
# 1660  nfp8334            7      1                   1                     0
# 1661  nfp8334            8      1                   1                     0
# 1662  nfp8334            9      1                   1                     0
# 1663  nfp8334           10      1                   1                     1
# 1664  nfp8334           11      1                   1                     2
#
# ...

# %%
period.describe()
# Out:
#        CycleNumber        Group  CycleWithPeakorNot  ReproductiveCategory  \
# count  1665.000000  1665.000000         1665.000000           1665.000000
# mean      8.040841     0.382583            0.912312              0.055255
# std       6.593686     0.486164            0.282925              0.479706
# min       1.000000     0.000000            0.000000              0.000000
# 25%       3.000000     0.000000            1.000000              0.000000
# 50%       7.000000     0.000000            1.000000              0.000000
# 75%      11.000000     1.000000            1.000000              0.000000
# max      45.000000     1.000000            1.000000              9.000000
#
#        LengthofCycle
# count    1665.000000
# mean       29.299099
# std         3.887932
# min        18.000000
# 25%        27.000000
# 50%        29.000000
# 75%        31.000000
# max        54.000000

# %%
period.head(20)
# Out:
#    ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0   nfp8122            1      0                   1                     0
# 1   nfp8122            2      0                   1                     0
# 2   nfp8122            3      0                   1                     0
# 3   nfp8122            4      0                   1                     0
# 4   nfp8122            5      0                   1                     0
# 5   nfp8122            6      0                   1                     0
# 6   nfp8122            7      0                   1                     0
# 7   nfp8122            8      0                   1                     2
# 8   nfp8122            9      0                   1                     0
# 9   nfp8122           10      0                   1                     0
# 10  nfp8122           11      0                   1                     0
# 11  nfp8122           12      0                   1                     0
# ...

# %%
period.tail(5)
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 1660  nfp8334            7      1                   1                     0
# 1661  nfp8334            8      1                   1                     0
# 1662  nfp8334            9      1                   1                     0
# 1663  nfp8334           10      1                   1                     1
# 1664  nfp8334           11      1                   1                     2
#
#       LengthofCycle MeanCycleLength EstimatedDayofOvulation  \
# 1660             29                                      19
# 1661             28                                      17
# 1662             28                                      16
# 1663             40                                      27
# 1664             24
#
#      LengthofLutealPhase FirstDayofHigh  ... Method Prevmethod Methoddate  \
# 1660                  10             13  ...
# 1661                  11             12  ...
# ...

# %%
period.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1665 entries, 0 to 1664
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ClientID                    1665 non-null   object
#  1   CycleNumber                 1665 non-null   int64
#  2   Group                       1665 non-null   int64
#  3   CycleWithPeakorNot          1665 non-null   int64
#  4   ReproductiveCategory        1665 non-null   int64
#  5   LengthofCycle               1665 non-null   int64
#  6   MeanCycleLength             1665 non-null   object
#  7   EstimatedDayofOvulation     1665 non-null   object
#  8   LengthofLutealPhase         1665 non-null   object
#  9   FirstDayofHigh              1665 non-null   object
#  10  TotalNumberofHighDays       1665 non-null   object
#  11  TotalHighPostPeak           1665 non-null   object
#  12  TotalNumberofPeakDays       1665 non-null   object
# ...

# %%
period.columns.tolist()
# Out:
# ['ClientID',
#  'CycleNumber',
#  'Group',
#  'CycleWithPeakorNot',
#  'ReproductiveCategory',
#  'LengthofCycle',
#  'MeanCycleLength',
#  'EstimatedDayofOvulation',
#  'LengthofLutealPhase',
#  'FirstDayofHigh',
#  'TotalNumberofHighDays',
#  'TotalHighPostPeak',
#  'TotalNumberofPeakDays',
#  'TotalDaysofFertility',
#  'TotalFertilityFormula',
#  'LengthofMenses',
#  'MeanMensesLength',
#  'MensesScoreDayOne',
#  'MensesScoreDayTwo',
#  'MensesScoreDayThree',
#  'MensesScoreDayFour',
#  'MensesScoreDayFive',
#  'MensesScoreDaySix',
#  'MensesScoreDaySeven',
#  'MensesScoreDayEight',
#  'MensesScoreDayNine',
#  'MensesScoreDayTen',
#  'MensesScoreDay11',
#  'MensesScoreDay12',
#  'MensesScoreDay13',
#  'MensesScoreDay14',
#  'MensesScoreDay15',
#  'TotalMensesScore',
#  'MeanBleedingIntensity',
#  'NumberofDaysofIntercourse',
#  'IntercourseInFertileWindow',
#  'UnusualBleeding',
#  'PhasesBleeding',
#  'IntercourseDuringUnusBleed',
#  'Age',
#  'AgeM',
#  'Maristatus',
# ...

# %%
period.shape
# Out:
# (1665, 80)

# %%
period.isnull().sum()
# Out:
# ClientID                0
# CycleNumber             0
# Group                   0
# CycleWithPeakorNot      0
# ReproductiveCategory    0
#                        ..
# NextpregM               0
# Spousesame              0
# SpousesameM             0
# Timeattemptpreg         0
# BMI                     0
# Length: 80, dtype: int64

# %%
period.corr()
# Out:
#                       CycleNumber     Group  CycleWithPeakorNot  \
# CycleNumber              1.000000 -0.143044           -0.044145
# Group                   -0.143044  1.000000            0.117341
# CycleWithPeakorNot      -0.044145  0.117341            1.000000
# ReproductiveCategory    -0.041373  0.092257            0.026865
# LengthofCycle           -0.100693  0.031945           -0.059731
#
#                       ReproductiveCategory  LengthofCycle
# CycleNumber                      -0.041373      -0.100693
# Group                             0.092257       0.031945
# CycleWithPeakorNot                0.026865      -0.059731
# ReproductiveCategory              1.000000       0.101333
# LengthofCycle                     0.101333       1.000000

# %%
sns.heatmap(period.corr())
# Out:
# <AxesSubplot:>

# %%
period=period.iloc[50:1000:10]
period
# Out:
#     ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 50   nfp8107            1      0                   1                     0
# 60   nfp8106            3      0                   1                     0
# 70   nfp8024           10      0                   1                     0
# 80   nfp8020            8      1                   1                     0
# 90   nfp8026            2      1                   1                     0
# ..       ...          ...    ...                 ...                   ...
# 950  nfp8190            2      1                   1                     0
# 960  nfp8193            2      0                   1                     0
# 970  nfp8195            4      0                   1                     0
# 980  nfp8196            3      1                   1                     0
# 990  nfp8197            1      0                   1                     0
#
#      LengthofCycle MeanCycleLength EstimatedDayofOvulation  \
# ...

# %%
sns.distplot(period.CycleNumber)
# Out:
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CycleNumber', ylabel='Density'>

# %%
sns.distplot(period.Group)
# Out:
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Group', ylabel='Density'>

# %%
sns.distplot(period.ReproductiveCategory)
# Out:
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ReproductiveCategory', ylabel='Density'>

# %%
plt.figure(figsize=(16, 5))
heatmap = sns.heatmap(period.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('correlation', fontdict={'fontsize':12}, pad=12);

# %%
x = period.drop('LengthofCycle',axis=1)
y = period['LengthofCycle']
print(x)
print(y)
print('shape of x = ', x.shape)
print('shape of y = ', y.shape)
# Out:
#     ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 50   nfp8107            1      0                   1                     0
# 60   nfp8106            3      0                   1                     0
# 70   nfp8024           10      0                   1                     0
# 80   nfp8020            8      1                   1                     0
# 90   nfp8026            2      1                   1                     0
# ..       ...          ...    ...                 ...                   ...
# 950  nfp8190            2      1                   1                     0
# 960  nfp8193            2      0                   1                     0
# 970  nfp8195            4      0                   1                     0
# 980  nfp8196            3      1                   1                     0
# 990  nfp8197            1      0                   1                     0
#
#     MeanCycleLength EstimatedDayofOvulation LengthofLutealPhase  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print('shape of x_train =', x_train.shape)
print('shape of y_train =', y_train.shape)
print('shape of x_test =', x_train.shape)
print('shape of y_test =', y_train.shape)
# Out:
# shape of x_train = (76, 79)
# shape of y_train = (76,)
# shape of x_test = (76, 79)
# shape of y_test = (76,)

# %%
x=np.array(x)
print(x)
# Out:
# [['nfp8107' 1 0 ... '1' '0' ' ']
#  ['nfp8106' 3 0 ... ' ' ' ' ' ']
#  ['nfp8024' 10 0 ... ' ' ' ' ' ']
#  ...
#  ['nfp8195' 4 0 ... ' ' ' ' ' ']
#  ['nfp8196' 3 1 ... ' ' ' ' ' ']
#  ['nfp8197' 1 0 ... '1' '0' '19.6484815909702']]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0])

plt.plot(tuple(x), tuple(y), 'g.')
plt.xlabel("x")
plt.ylabel("ReproductiveCategory")
plt.show()

# %%
period.max()
# Out:
# ClientID                         nfp8197
# CycleNumber                           27
# Group                                  1
# CycleWithPeakorNot                     1
# ReproductiveCategory                   1
#                               ...
# NextpregM                              7
# Spousesame                             1
# SpousesameM                            1
# Timeattemptpreg                        0
# BMI                     49.9171597633136
# Length: 80, dtype: object

# %%
period.mean()
# Out:
# C:\Users\sushmitha\AppData\Local\Temp\ipykernel_10344\1143328088.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   period.mean()
# CycleNumber                    7.294737e+00
# Group                          3.894737e-01
# CycleWithPeakorNot             9.157895e-01
# ReproductiveCategory           3.157895e-02
# LengthofCycle                  2.887368e+01
# TotalNumberofHighDays          1.552784e+98
# TotalHighPostPeak              1.273684e+72
# TotalFertilityFormula         1.694865e+181
# LengthofMenses                 4.689585e+93
# MensesScoreDayOne              1.181181e+92
# MensesScoreDayTwo              2.350772e+92
# MensesScoreDayNine             1.052632e-02
# MensesScoreDayTen              1.052632e-02
# TotalMensesScore              7.043173e+140
# NumberofDaysofIntercourse      3.527824e+96
# ...

# %%
period.mode()
# Out:
#   ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0  nfp8066          1.0    0.0                 1.0                   0.0
# 1  nfp8173          NaN    NaN                 NaN                   NaN
#
#    LengthofCycle MeanCycleLength EstimatedDayofOvulation LengthofLutealPhase  \
# 0           28.0                                      13                  13
# 1            NaN             NaN                     NaN                 NaN
#
#   FirstDayofHigh  ... Method Prevmethod Methoddate Whychart Nextpreg  \
# 0                 ...
# 1            NaN  ...    NaN        NaN        NaN      NaN      NaN
#
#   NextpregM Spousesame SpousesameM Timeattemptpreg  BMI
# 0
# 1       NaN        NaN         NaN             NaN  NaN
#
# [2 rows x 80 columns]

# %%
period.median()
# Out:
# C:\Users\sushmitha\AppData\Local\Temp\ipykernel_10344\2480439568.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   period.median()
# CycleNumber                    7.0
# Group                          0.0
# CycleWithPeakorNot             1.0
# ReproductiveCategory           0.0
# LengthofCycle                 28.0
# TotalNumberofHighDays          3.0
# TotalHighPostPeak              0.0
# TotalFertilityFormula         13.0
# LengthofMenses                 5.0
# MensesScoreDayOne              2.0
# MensesScoreDayTwo              3.0
# TotalMensesScore              10.0
# NumberofDaysofIntercourse      3.0
# IntercourseInFertileWindow     0.0
# dtype: float64

# %%
period.min()
# Out:
# ClientID                nfp8020
# CycleNumber                   1
# Group                         0
# CycleWithPeakorNot            0
# ReproductiveCategory          0
#                          ...
# NextpregM
# Spousesame
# SpousesameM
# Timeattemptpreg
# BMI
# Length: 80, dtype: object

# %%
period.corr()
# Out:
#                       CycleNumber     Group  CycleWithPeakorNot  \
# CycleNumber              1.000000 -0.084936           -0.090192
# Group                   -0.084936  1.000000            0.164466
# CycleWithPeakorNot      -0.090192  0.164466            1.000000
# ReproductiveCategory    -0.077992 -0.020790            0.054759
# LengthofCycle            0.018663 -0.158867           -0.247421
#
#                       ReproductiveCategory  LengthofCycle
# CycleNumber                      -0.077992       0.018663
# Group                            -0.020790      -0.158867
# CycleWithPeakorNot                0.054759      -0.247421
# ReproductiveCategory              1.000000       0.126569
# LengthofCycle                     0.126569       1.000000

# %%
period["CycleNumber"].var()
# Out:
# 28.529227323628223

# %%
period["ReproductiveCategory"].std()
# Out:
# 0.17580402404729126

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='CycleWithPeakorNot',y='Group',data=period)
# Out:
# <AxesSubplot:xlabel='CycleWithPeakorNot', ylabel='Group'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(period.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
columns = ['ReproductiveCategory', 'CycleWithPeakorNot', 'LengthofCycle','CycleNumber','']  # Replace with your actual column names
for column in columns:
    plt.figure(figsize=(25, 6))
    sns.countplot(x=period[column], data=period, palette='hls')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
sns.pairplot(period)

# %%
fig, ax = plt.subplots(figsize=(20,10))  
sns.heatmap(period.corr(),annot=True,cmap = "crest")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
columns = ['LengthofCycle', 'Group', 'ReproductiveCategory','CycleNumber','CycleWithPeakorNot']  # Replace with your actual column names

for column in columns:
    plt.figure(figsize=(25, 6))
    sns.countplot(x=period[column], data=period, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
columns = ['LengthofCycle', 'Group', 'ReproductiveCategory','CycleNumber','CycleWithPeakorNot']  # Replace with your actual column names

for column in columns:
    plt.figure(figsize=(25, 6))
    sns.swarmplot(x=period[column], data=period, palette='hls')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 37.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
columns = ['LengthofCycle', 'Group', 'ReproductiveCategory','CycleNumber','CycleWithPeakorNot']
for column in columns:
    sns.violinplot(x='LengthofCycle', y=column, data=period)
    plt.xlabel('Group')
    plt.ylabel(column)
    plt.title(f'{column} vs LengthofCycle')
    plt.show()

# %%
#period tracker is completed
